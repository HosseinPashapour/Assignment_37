# %% [markdown]
# # Matplotlib Getting Started

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.9.0

# %% [markdown]
# # Matplotlib Pyplot

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.title("Matplotlib Pyplot")

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.title("Matplotlib Plotting")
plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.plot(xpoints, ypoints, "o")
plt.title("Plotting Without Line")
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.title("Multiple Points")
plt.plot(xpoints, ypoints)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])
plt.title("Default X-Points")
plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Matplotlib Markers

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Markers")
plt.plot(ypoints, marker = 'o')
plt.show()

# %% [markdown]
# # Format Strings fmt  (Marker|line|color)

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Format Strings fmt  (Marker|line|color)")
plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# # Marker Size

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Marker Size")
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# # Marker Color

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Marker Color")
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Marker Color")
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Marker Color")
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
plt.show()

# %% [markdown]
# # Matplotlib Line (Linestyle)

# %%
ypoints = np.array([3, 8, 1, 10])
plt.title("Matplotlib Line (Linestyle)")
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.title("Linestyle")
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# # Shorter Syntax

# %%
plt.title("Shorter Syntax")
plt.plot(ypoints, ls = ':')

# %% [markdown]
# # Line Color

# %%
plt.plot(ypoints, color = 'r')
plt.title("Line Color")
plt.show()

# %% [markdown]
# # Line Width

# %%
plt.plot(ypoints, linewidth = '15')
plt.title("Line Width")
plt.show()

# %% [markdown]
# # Multiple Lines

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])
plt.title("Multiple Lines")
plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.title("Multiple Lines")
plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# # Matplotlib Labels and Title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)
plt.title("Matplotlib Labels and Title")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Create a Title for a Plot

# %%
plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Set Font Properties for Title and Labels

# %%
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Position the Title

# %%
plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %% [markdown]
# # Matplotlib Adding Grid Lines

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %% [markdown]
# ## Specify Which Grid Lines to Display

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %% [markdown]
# ## Set Line Properties for the Grid

# %%
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)

plt.show()

# %% [markdown]
# # Matplotlib Subplot

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.title("Matplotlib Subplot")
plt.subplot(1, 2, 1)   # the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)   # the figure has 1 row, 2 columns, and this plot is the second plot.
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# ## Title

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# ## Super Title

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# # Matplotlib Scatter

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.title("Matplotlib Scatter")
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ## Compare Plots

# %%
#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.title("Compare Plots")
#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# ## Colors

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')
plt.title("Colors")
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %% [markdown]
# ## Color Each Dot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.title("Color Each Dot")
plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# ## ColorMap

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.title("ColorMap")
plt.show()

# %%
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.title("ColorMap")
plt.colorbar()

plt.show()

# %% [markdown]
# ## Size

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.title("Size")
plt.scatter(x, y, s=sizes)

plt.show()

# %% [markdown]
# ## Alpha

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)
plt.title("Alpha")
plt.show()

# %% [markdown]
# ## Combine Color Size and Alpha

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
plt.title("Combine Color Size and Alpha")
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Matplotlib Bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.title("Matplotlib Bars")
plt.bar(x,y)
plt.show()

# %% [markdown]
# ## Horizontal Bars

# %%
plt.barh(x, y)
plt.title("Horizontal Bars")
plt.show()

# %% [markdown]
# ## Bar Color

# %%
plt.bar(x, y, color = "red")
plt.title("Bar Color")
plt.show()

# %%
plt.bar(x, y, color = "hotpink")
plt.title("Bar Color")
plt.show()

# %%
plt.bar(x, y, color = "#4CAF50")
plt.title("Bar Color")
plt.show()

# %% [markdown]
# ## Bar Width

# %%
plt.bar(x, y, width = 0.1)
plt.title("Bar Width")
plt.show()

# %% [markdown]
# ## Bar Height

# %%
plt.barh(x, y, height = 0.1)
plt.title("Bar Height")
plt.show()

# %% [markdown]
# # Matplotlib Histograms

# %%
x = np.random.normal(170, 10, 250)
plt.title("Matplotlib Histograms")
print(x)
# Out:
# [162.30483115 190.27748695 161.28699847 187.60176618 171.31522368
#  165.78643165 164.05143976 180.8994404  162.01070993 178.12609054
#  169.06797606 165.34949724 170.94866532 179.08814822 148.45579812
#  153.73305636 176.08821715 187.39412612 156.05628086 168.35838021
#  177.9558013  177.90596935 159.1466693  182.99338525 158.54825762
#  174.41396866 182.94800414 177.07447579 170.61381368 154.29835643
#  152.56780217 154.07020257 187.54783331 177.86850306 163.43489807
#  172.68421648 153.03028902 155.51749835 159.54231561 167.0007195
#  176.81023811 161.26747908 155.56534474 168.4151639  180.5023166
#  166.10413068 170.9492245  177.09320179 179.79712487 179.38248413
#  168.94678982 160.37019322 170.25643208 165.22929146 155.25773521
#  156.63614548 163.55963629 161.81895063 178.14716775 169.20926018
#  156.65359634 187.1456153  164.69251203 154.52020158 159.03709322
#  186.47431302 157.12708142 170.46907034 167.5173925  185.25644903
#  160.59819913 188.54343808 158.81593759 176.60849085 172.10145973
#  164.30300395 166.78496001 157.27360603 160.04881191 180.92283093
#  153.59162751 169.79569668 156.68483103 169.93572652 174.1175018
#  171.75835107 170.4935659  182.1177118  177.29105377 185.41188231
#  171.7884416  184.89240861 167.6175324  162.54316488 173.8941837
#  163.57623776 177.2366252  163.18373812 170.83605591 161.97268629
#  177.64552265 175.27409333 178.84585479 180.27881502 182.35329683
#  181.0522707  170.65627383 163.1315344  182.98711972 163.30175266
#  166.58105592 169.33807227 178.12353199 172.61540694 163.89903941
#  161.63474437 153.13406725 182.79379604 172.73302057 180.07822968
#  171.5922415  179.14179047 182.32529476 161.43500214 174.237524
#  164.92122413 157.95121914 166.60247864 155.73708749 158.50857197
#  188.6955415  160.4568892  187.33134286 175.68194492 179.54910271
#  168.79009276 165.73917806 161.8045604  173.46281644 171.51639695
#  175.0683734  165.58070637 157.77634984 161.59990429 162.18817883
#  166.87514998 171.53939149 152.44053616 168.63385328 157.76171407
#  175.95972178 171.88691924 170.43220893 174.72429098 176.19196134
#  186.47868306 180.68728831 161.26231528 174.89979072 167.83930637
#  163.28978397 159.56747077 164.58396305 157.36608078 172.81921957
#  179.73096093 148.17662902 162.19323733 165.06091734 184.76091682
#  177.3437637  165.33422577 181.88633997 165.30696088 172.16319838
#  157.00583495 181.6768469  175.21573606 177.45593103 161.37084838
#  159.53981071 186.67342967 178.19969206 180.43684849 170.40803921
#  160.22996537 145.94447366 158.36577889 166.66297077 171.58864949
#  165.75473401 166.7726744  157.38909999 166.58066952 171.42303098
#  175.76535026 173.3716904  163.95570149 173.46476501 171.86823805
#  158.56718705 163.23066188 171.83141325 167.39016797 166.81606506
#  186.7727683  165.20644094 172.74647094 148.26092733 164.46942148
#  176.99172089 172.06915823 175.28000894 160.84665394 160.87207227
#  169.28176166 155.96530687 177.16641528 161.78319359 164.87240459
#  172.97521697 177.57991825 166.20897653 162.80634505 152.71853209
#  161.7051194  178.33908282 157.51883841 158.79593196 162.29526278
#  171.24927923 164.16386376 177.49871346 165.28659837 170.89545103
#  177.68091353 182.12119317 173.42586273 171.75646545 173.56354576
#  169.5935265  179.23400458 179.19013395 174.84145482 168.07995104
#  174.71615477 160.56749126 177.05439675 160.17228025 170.85412018]

# %%
plt.hist(x)
plt.title("Matplotlib Histograms")
plt.show()

# %% [markdown]
# # Matplotlib Pie Charts

# %%
y = np.array([35, 25, 25, 15])
plt.title("Matplotlib Pie Charts")
plt.pie(y)
plt.show()

# %% [markdown]
# ## Labels

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.title("Labels")
plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# ## Start Angle

# %%
plt.pie(y, labels = mylabels, startangle = 90)
plt.title("Start Angle")
plt.show()

# %% [markdown]
# ## Explode

# %%
myexplode = [0.2, 0, 0, 0]
plt.title("Explode")
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# ## Shadow

# %%
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.title("Shadow")
plt.show()

# %% [markdown]
# ## Colors

# %%
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.title("Colors")
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# ## Legend

# %%
plt.pie(y, labels = mylabels)
plt.title("Legend")
plt.legend()
plt.show()

# %% [markdown]
# ## Legend With Header

# %%
plt.pie(y, labels = mylabels)
plt.title("LegeLegend With Headernd")
plt.legend(title = "Four Fruits:")
plt.show()
